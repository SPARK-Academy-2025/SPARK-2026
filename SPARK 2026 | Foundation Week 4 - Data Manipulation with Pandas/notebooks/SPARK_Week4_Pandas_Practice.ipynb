# %% [markdown]
# # 🧠 SPARK Academy 2026 — Week 4 Practice Notebook
# ## Data Manipulation with Pandas
#
# **Instructions:**
# - Work through each exercise in order
# - Each exercise has a **Task** cell (read it) and a **Code** cell (write your solution)
# - Run the setup cell first — it creates the dataset you'll use throughout
# - Some exercises build on previous ones
# - Medical imaging context throughout — this is real-world practice!
#
# ---

# %% [markdown]
# ## 🔧 Setup — Run This First!

# %%
import pandas as pd
import numpy as np

# Hospital patient scan dataset — you'll use this throughout
patients = pd.DataFrame({
    "patient_id": ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010",
                   "P011", "P012", "P013", "P014", "P015", "P016", "P017", "P018", "P019", "P020"],
    "name": ["Fatima", "Chidi", "Amina", "Bola", "Kofi", "Dayo", "Emeka", "Ama", "Tunde", "Ngozi",
             "Kwame", "Aisha", "Obinna", "Zainab", "Yaw", "Halima", "Ife", "Segun", "Adaeze", "Musa"],
    "age": [52, 34, 45, 28, 61, np.nan, 39, 55, 48, 33,
            67, 41, np.nan, 29, 58, 44, 36, 50, 43, np.nan],
    "gender": ["F", "M", "F", "M", "M", "M", "M", "F", "M", "F",
               "M", "F", "M", "F", "M", "F", "F", "M", "F", "M"],
    "country": ["Nigeria", "Nigeria", "Ghana", "Nigeria", "Ghana", "Nigeria", "Nigeria", "Ghana",
                "Nigeria", "Nigeria", "Ghana", "Kenya", "Nigeria", "Kenya", "Ghana", "Nigeria",
                "Nigeria", "Nigeria", "Nigeria", "Kenya"],
    "scan_type": ["MRI", "CT", "MRI", "X-Ray", "CT", "MRI", "CT", "MRI", "X-Ray", "CT",
                  "MRI", "CT", "MRI", "X-Ray", "CT", "MRI", "CT", "MRI", "X-Ray", "MRI"],
    "tumor_cm": [3.5, 1.2, 4.1, 0.8, 2.3, 1.9, np.nan, 3.8, 0.5, 1.1,
                 4.5, 2.7, 3.2, np.nan, 1.8, 2.1, 0.9, 3.6, 2.4, 1.5],
    "diagnosis": ["Glioma", "Normal", "Meningioma", "Normal", "Glioma", "Astrocytoma", "Normal",
                  "Glioma", "Normal", "Normal", "Meningioma", "Glioma", "Glioma", "Normal",
                  "Normal", "Astrocytoma", "Normal", "Meningioma", "Glioma", "Normal"],
    "blood_pressure": ["140/90", "120/80", "135/85", "118/75", "150/95", "125/82", "130/85",
                       "142/92", "115/70", "122/78", "155/98", "128/84", "138/88", "110/72",
                       "132/86", "126/80", "119/76", "145/93", "130/85", "120/80"],
    "scan_date": ["2025-01-15", "2025-01-16", "2025-01-15", "2025-02-01", "2025-01-20",
                  "2025-02-05", "2025-01-18", "2025-02-10", "2025-01-22", "2025-02-12",
                  "2025-01-25", "2025-02-15", "2025-01-28", "2025-02-18", "2025-02-01",
                  "2025-02-20", "2025-02-05", "2025-02-22", "2025-02-25", "2025-03-01"]
})

print("✅ Dataset loaded!")
print(f"Shape: {patients.shape}")
print(f"Columns: {patients.columns.tolist()}")

# %% [markdown]
# ---
# ## 📊 Part 1: Exploring the Data
# *Get familiar with the dataset before doing anything else*
#
# ---

# %% [markdown]
# ### Exercise 1: First Look
# **Task:** Display the first 5 rows, last 3 rows, and the shape of the dataset.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Data Types
# **Task:** Use `.info()` to check the data types and missing values. Then print just the column names as a list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Quick Stats
# **Task:** Run `.describe()` on the dataset. What is the average age? What is the largest tumor size?

# %%
# Your code here

# %% [markdown]
# ---
# ## 🔍 Part 2: Selecting Data
# *Pull out the specific data you need*
#
# ---

# %% [markdown]
# ### Exercise 4: Select Columns
# **Task:**
# 1. Select just the `name` column (as a Series) and print it
# 2. Select `name`, `diagnosis`, and `tumor_cm` columns (as a DataFrame) and print it

# %%
# Your code here

# %% [markdown]
# ### Exercise 5: Select Rows
# **Task:**
# 1. Use `.iloc` to get the first 3 patients
# 2. Use `.loc` to get patient at index 5, showing only their `name` and `diagnosis`

# %%
# Your code here

# %% [markdown]
# ### Exercise 6: Filter — Critical Patients
# **Task:** Filter the dataset to show only patients where `tumor_cm > 3.0`. How many critical patients are there?

# %%
# Your code here

# %% [markdown]
# ### Exercise 7: Filter — Multiple Conditions
# **Task:** Find all **female patients** from **Nigeria** who had an **MRI** scan.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8: Filter — Diagnosis Groups
# **Task:** Find all patients whose diagnosis is either `"Glioma"` or `"Meningioma"` (Hint: use `.isin()`)

# %%
# Your code here

# %% [markdown]
# ---
# ## 🧹 Part 3: Data Cleaning
# *Handle the messy reality of hospital data*
#
# ---

# %% [markdown]
# ### Exercise 9: Find Missing Values
# **Task:** Check how many missing values each column has. Which columns have missing data?

# %%
# Your code here

# %% [markdown]
# ### Exercise 10: Fill Missing Ages
# **Task:** Fill the missing `age` values with the **median** age. Verify there are no more missing ages.

# %%
# Your code here

# %% [markdown]
# ### Exercise 11: Handle Missing Tumor Sizes
# **Task:** Since tumor measurement is critical, **drop** the rows where `tumor_cm` is missing. Print the new shape.

# %%
# Your code here

# %% [markdown]
# ### Exercise 12: Check for Duplicates
# **Task:** Check if there are any duplicate rows in the dataset. Print the count.

# %%
# Your code here

# %% [markdown]
# ### Exercise 13: Convert Scan Date
# **Task:** Convert the `scan_date` column from string to datetime using `pd.to_datetime()`. Print the dtype to confirm.

# %%
# Your code here

# %% [markdown]
# ---
# ## ⚙️ Part 4: Transforming Data
# *Create new columns and modify existing ones*
#
# ---

# %% [markdown]
# ### Exercise 14: Add a Status Column
# **Task:** Create a new column called `status` based on `tumor_cm`:
# - tumor > 3.0 → `"Critical"`
# - tumor > 1.5 → `"Monitor"`
# - tumor <= 1.5 → `"Stable"`
#
# Print `value_counts()` of the new column.

# %%
# Your code here

# %% [markdown]
# ### Exercise 15: Convert Units
# **Task:** Create a new column `tumor_mm` that converts `tumor_cm` to millimeters (multiply by 10).

# %%
# Your code here

# %% [markdown]
# ### Exercise 16: Extract Blood Pressure
# **Task:** The `blood_pressure` column has format "systolic/diastolic". Split it into two new columns:
# - `bp_systolic` (as integer)
# - `bp_diastolic` (as integer)
#
# Hint: Use `.str.split("/", expand=True)`

# %%
# Your code here

# %% [markdown]
# ### Exercise 17: Age Groups
# **Task:** Create an `age_group` column:
# - age < 35 → `"Young Adult"`
# - age < 50 → `"Middle Aged"`
# - age >= 50 → `"Senior"`
#
# Print the value_counts().

# %%
# Your code here

# %% [markdown]
# ### Exercise 18: Sort by Urgency
# **Task:** Sort the dataset by `tumor_cm` in descending order (largest tumors first). Display the top 5 with only `name`, `tumor_cm`, and `diagnosis`.

# %%
# Your code here

# %% [markdown]
# ---
# ## 📈 Part 5: Descriptive Statistics & GroupBy
# *Analyze and summarize your data*
#
# ---

# %% [markdown]
# ### Exercise 19: Value Counts
# **Task:**
# 1. How many patients have each `diagnosis`? Use `value_counts()`
# 2. How many patients from each `country`?
# 3. How many of each `scan_type`?

# %%
# Your code here

# %% [markdown]
# ### Exercise 20: GroupBy — Average Tumor by Diagnosis
# **Task:** Calculate the **mean tumor size** for each diagnosis using `groupby()`. Which diagnosis has the largest average tumor?

# %%
# Your code here

# %% [markdown]
# ### Exercise 21: GroupBy — Country Stats
# **Task:** For each country, calculate:
# - Number of patients (count)
# - Average age
# - Average tumor size
#
# Hint: Use `.agg()`

# %%
# Your code here

# %% [markdown]
# ### Exercise 22: Correlation
# **Task:** Calculate the correlation between `age` and `tumor_cm`. Is there a relationship?

# %%
# Your code here

# %% [markdown]
# ### Exercise 23: GroupBy — Scan Type Breakdown
# **Task:** For each `scan_type`, find the **count**, **mean**, and **max** of `tumor_cm`.

# %%
# Your code here

# %% [markdown]
# ---
# ## 🏆 Part 6: Putting It All Together
# *Mini-projects that combine everything you learned*
#
# ---

# %% [markdown]
# ### Exercise 24: Complete Cleaning Pipeline
# **Task:** Starting from the original `patients` DataFrame:
# 1. Fill missing ages with the median
# 2. Drop rows with missing tumor_cm
# 3. Convert scan_date to datetime
# 4. Add the `status` column (Critical/Monitor/Stable)
# 5. Print the shape and info() of your clean dataset
#
# Store the result in a variable called `df_clean`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 25: Clinical Report
# **Task:** Using your `df_clean` DataFrame, generate a mini clinical report by printing:
# 1. Total number of patients
# 2. Gender distribution (value_counts)
# 3. Number of Critical vs Monitor vs Stable patients
# 4. The 3 patients with the largest tumors (name, age, tumor_cm, diagnosis)
# 5. Average tumor size by country

# %%
# Your code here

# %% [markdown]
# ### Exercise 26: Nigerian MRI Analysis
# **Task:** Filter for only **Nigerian patients** who had **MRI scans**. Then:
# 1. How many are there?
# 2. What is their average tumor size?
# 3. What diagnoses do they have? (value_counts)

# %%
# Your code here

# %% [markdown]
# ### Exercise 27: Save Your Results
# **Task:**
# 1. Save the full `df_clean` DataFrame to `"cleaned_patients.csv"` (without the index)
# 2. Filter for only Critical patients and save to `"critical_patients.csv"`
# 3. Verify by loading `"critical_patients.csv"` back and printing its shape

# %%
# Your code here

# %% [markdown]
# ### Exercise 28: 🧠 Boss Challenge — Hospital Dashboard
# **Task:** Create a complete dashboard dictionary with these keys:
# - `"total_patients"` → total count
# - `"countries"` → list of unique countries
# - `"avg_age"` → average age rounded to 1 decimal
# - `"diagnosis_counts"` → dictionary of diagnosis value_counts
# - `"critical_patients"` → list of names of critical patients (tumor > 3.0)
# - `"country_with_most_patients"` → name of country with the most patients
# - `"most_common_scan"` → most common scan type
# - `"avg_tumor_by_diagnosis"` → dictionary of mean tumor size per diagnosis (rounded to 2 decimals)
#
# Print each key-value pair on a separate line.

# %%
# Your code here

# %% [markdown]
# ---
# ## ✅ Great Work!
#
# You've practiced:
# - ✅ Loading and exploring data (head, shape, info, describe)
# - ✅ Selecting columns and rows (loc, iloc, boolean indexing)
# - ✅ Filtering with single and multiple conditions
# - ✅ Handling missing values (isnull, fillna, dropna)
# - ✅ Transforming data (new columns, type conversion, string operations)
# - ✅ Descriptive statistics (describe, mean, value_counts, groupby, corr)
# - ✅ Saving results to CSV
# - ✅ Building a complete data analysis pipeline
#
# **Next:** Complete the Week 4 Team Capstone Project!
#
# ---
# *SPARK Academy 2026 — Train for Change, From Science to Practice* 🚀
